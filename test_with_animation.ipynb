# %%
import pickle 
import pandas as pd
import numpy as np

with open('./knn_model.pkl', 'rb') as f:
    knn_model = pickle.load(f)

base = pd.read_csv("./random_selected_test_rows.csv")
del base[base.columns[0]]
base.head()
# Out:
#               class  SENSOR0_RMS  SENSOR0_WAVELEN  SENSOR0_WAMP  \
# 0  finger_abduction     0.073744        24.143499           674
# 1  finger_abduction     0.073744        24.143499           674
# 2  finger_abduction     0.073744        24.143499           674
# 3  finger_abduction     0.073744        24.143499           674
# 4  finger_abduction     0.073744        24.143499           674
#
#    SENSOR0_APPEN  SENSOR0_SAMPEN  SENSOR0_MAV  SENSOR1_RMS  SENSOR1_WAVELEN  \
# 0       0.783162        0.604518     0.051414     0.055694        19.768599
# 1       0.783162        0.604518     0.051414     0.055694        19.768599
# 2       0.783162        0.604518     0.051414     0.055694        19.768599
# 3       0.783162        0.604518     0.051414     0.055694        19.768599
# 4       0.783162        0.604518     0.051414     0.055694        19.768599
#
#    SENSOR1_WAMP  ...  SENSOR2_WAMP  SENSOR2_APPEN  SENSOR2_SAMPEN  \
# ...

# %%
base['class'].unique()
# Out:
# array(['finger_abduction', 'rest', 'flexion', 'ulnar_deviation', 'grip',
#        'extension', 'supination', 'radial_deviation', 'finger_adduction',
#        'pronation'], dtype=object)

# %%
classes = ['extension', 'finger_abduction', 'finger_adduction', 'flexion', 'grip',
 'pronation', 'radial_deviation', 'rest', 'supination', 'ulnar_deviation']
knn_model
# Out:
# KNeighborsClassifier()

# %%
target_cols = 'class'
train_cols = ['SENSOR0_RMS', 'SENSOR1_RMS', 'SENSOR2_RMS', 'SENSOR3_RMS', 'SENSOR0_APPEN', 'SENSOR1_APPEN', 'SENSOR2_APPEN', 'SENSOR3_APPEN']

# %%
t = base.loc[(base['class'] == "grip") | (base['class'] == "rest") | (base['class'] == "flexion")]
t['class'].value_counts()
# Out:
# class
# grip       280
# flexion    279
# rest       161
# Name: count, dtype: int64

# %%
# TODO: Temporary uses only GRIP, REST and FLEXION
t_base = base.loc[(base['class'] == "grip") | (base['class'] == "rest") | (base['class'] == "flexion")]

r_row = np.random.randint(0, len(t_base))
test_one = t_base.iloc[r_row]

X = test_one[train_cols]
Y = test_one[target_cols]
X, Y
# Out:
# (SENSOR0_RMS      0.042264
#  SENSOR1_RMS      0.142586
#  SENSOR2_RMS      0.012958
#  SENSOR3_RMS      0.002289
#  SENSOR0_APPEN    0.992678
#  SENSOR1_APPEN    0.819739
#  SENSOR2_APPEN    0.979885
#  SENSOR3_APPEN    0.935548
#  Name: 781, dtype: object,
#  'grip')

# %%
import connection
connection.con()

# %%
predict_classes = knn_model.predict([X])
classes[predict_classes[0]]
# Out:
# /home/beloin/Documents/aulas/hand-classifier/.venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 'grip'

# %%
connection.send_movement(classes[predict_classes[0]].upper())

# %%
r_row = np.random.randint(0, len(t_base))
test_one = t_base.iloc[r_row]

X = test_one[train_cols]
Y = test_one[target_cols]
X, Y
# Out:
# (SENSOR0_RMS      0.137395
#  SENSOR1_RMS      0.045053
#  SENSOR2_RMS      0.020845
#  SENSOR3_RMS      0.675548
#  SENSOR0_APPEN     0.89314
#  SENSOR1_APPEN    0.811959
#  SENSOR2_APPEN    0.849185
#  SENSOR3_APPEN    0.789285
#  Name: 124, dtype: object,
#  'rest')

# %%
predict_classes = knn_model.predict([X])
pred_class = classes[predict_classes[0]].upper()
print(pred_class)
connection.send_movement(pred_class)
# Out:
# REST
# /home/beloin/Documents/aulas/hand-classifier/.venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
r_row = np.random.randint(0, len(t_base))
test_one = t_base.iloc[r_row]

X = test_one[train_cols]
Y = test_one[target_cols]
X, Y
# Out:
# (SENSOR0_RMS      0.034833
#  SENSOR1_RMS      0.023569
#  SENSOR2_RMS      0.009418
#  SENSOR3_RMS      0.001883
#  SENSOR0_APPEN    0.903185
#  SENSOR1_APPEN    0.833928
#  SENSOR2_APPEN    0.898198
#  SENSOR3_APPEN    0.855803
#  Name: 1157, dtype: object,
#  'flexion')

# %%
predict_classes = knn_model.predict([X])
pred_class = classes[predict_classes[0]].upper()
print(pred_class)
connection.send_movement(pred_class)
# Out:
# FLEXION
# /home/beloin/Documents/aulas/hand-classifier/.venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
